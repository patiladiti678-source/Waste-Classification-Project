# %% [markdown]
# # Week 1 Notebook
# This notebook contains:
# - Project selection (Waste Classification)
# - Dataset collected from Kaggle
# - Uploaded dataset to Google Drive
# - Initial setup done
